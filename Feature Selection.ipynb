# %% [markdown]
# - <a href='#1'>Prepare</a>
# - <a href='#2'>Feature Selection</a>
#     - <a href='#2-1'>1. Filter</a>
#         - <a href='#2-1-1'>1.1 Pearson Correlation</a>
#         - <a href='#2-1-2'>1.2 Chi-2</a>
#     - <a href='#2-2'>2. Wrapper</a>
#     - <a href='#2-3'>3. Embeded</a>
#         - <a href='#2-3-1'>3.1 Logistics Regression L1</a>
#         - <a href='#2-3-2'>3.2 Random Forest</a>
#         - <a href='#2-3-3'>3.3 LightGBM</a>
# - <a href='#3'>Summary</a>

# %% [markdown]
# # <a id='1'>Prepare</a>

# %%
import pandas as pd
import numpy as np
import gc
import warnings
warnings.filterwarnings("ignore")
application_train = pd.read_csv('data/application_train.csv')

bur_cluster = pd.read_csv('feature/bur_cluster.csv')
bureau_feature = pd.read_csv('feature/bureau_feature.csv')
ccb_feature = pd.read_csv('feature/ccb_feature.csv')
ip_feature = pd.read_csv('feature/ip_feature.csv')
pcb_feature = pd.read_csv('feature/pcb_feature.csv')
pa_feature = pd.read_csv('feature/pa_feature.csv')
print(len(list(bur_cluster.columns)), len(bureau_feature.columns), len(ccb_feature.columns), len(ip_feature.columns), len(pcb_feature.columns), len(pa_feature.columns))

for i in [bur_cluster, bureau_feature, ccb_feature, ip_feature, pcb_feature, pa_feature]:
    application_train = application_train.join(i, how='left', on='SK_ID_CURR', lsuffix='_left',rsuffix='_right')
    application_train['SK_ID_CURR'] = application_train['SK_ID_CURR_left'].values
    del application_train['SK_ID_CURR_left']
    del application_train['SK_ID_CURR_right']
# Out:
# 2 73 21 48 32 118

# %%
application_train.shape
# Out:
# (307511, 410)

# %% [markdown]
# ### Stratified Sampling (ratio = 0.1)

# %%
application_sample1 = application_train.loc[application_train.TARGET==1].sample(frac=0.1, replace=False)
print('label 1 sample size:', str(application_sample1.shape[0]))
application_sample0 = application_train.loc[application_train.TARGET==0].sample(frac=0.1, replace=False)
print('label 0 sample size:', str(application_sample0.shape[0]))
application = pd.concat([application_sample1, application_sample0], axis=0).sort_values('SK_ID_CURR')
# Out:
# label 1 sample size: 2482
# label 0 sample size: 28269

# %% [markdown]
# ### Impute missing values

# %%
categorical_list = []
numerical_list = []
for i in application.columns.tolist():
    if application[i].dtype=='object':
        categorical_list.append(i)
    else:
        numerical_list.append(i)
print('Number of categorical features:', str(len(categorical_list)))
print('Number of numerical features:', str(len(numerical_list)))
# Out:
# Number of categorical features: 16
# Number of numerical features: 394

# %%
from sklearn.impute import SimpleImputer
application[numerical_list] = application[numerical_list].replace([np.inf, -np.inf], np.nan)
application[numerical_list] = SimpleImputer(strategy='median').fit_transform(application[numerical_list])
# application[numerical_list] = SimpleImputer(missing_values=np.inf, strategy='median').fit_transform(application[numerical_list])

# %% [markdown]
# ### Deal with Categorical features: OneHotEncoding

# %%
# 独热
del application_train; gc.collect()
application = pd.get_dummies(application, drop_first=True)
print(application.shape)
# Out:
# (30751, 515)

# %% [markdown]
# ### Feature matrix and target

# %%
X = application.drop(['SK_ID_CURR', 'TARGET'], axis=1)
y = application.TARGET
feature_name = X.columns.tolist()

# %% [markdown]
# # <a id='2'>Feature Selection</a>
# - select **100** features from 226
# - **xxx_support**: list to represent select this feature or not
# - **xxx_feature**: the name of selected features

# %% [markdown]
# ## <a id='2-1'>1 Filter</a>
# - documentation for **SelectKBest**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html
#
# ###  <a id='2-1-1'>1.1 Pearson Correlation</a>
# **Note**
# - Normalization: no
# - Impute missing values: yes

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature

# %%
cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ###  <a id='2-1-2'>1.2 Chi-2</a>
#
# **Note**
# - Normalization: MinMaxScaler (values should be bigger than 0)
# - Impute missing values: yes

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.preprocessing import MinMaxScaler
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
# Out:
# SelectKBest(k=100, score_func=<function chi2 at 0x17fbf1940>)

# %%
application[numerical_list].replace(np.inf, np.nan).max().max()
# Out:
# 100876407.92556468

# %%
application[numerical_list].max().max()
# Out:
# 100876407.92556468

# %%
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ## <a id='2-2'>2. Wrapper</a>
# - documentation for **RFE**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#
# **Note**
# - Normalization: depend on the used model; yes for LR
# - Impute missing values: depend on the used model; yes for LR

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
rfe_selector.fit(X_norm, y)
# Out:
# Fitting estimator with 513 features.
# Fitting estimator with 503 features.
# Fitting estimator with 493 features.
# Fitting estimator with 483 features.
# Fitting estimator with 473 features.
# Fitting estimator with 463 features.
# Fitting estimator with 453 features.
# Fitting estimator with 443 features.
# Fitting estimator with 433 features.
# Fitting estimator with 423 features.
# Fitting estimator with 413 features.
# Fitting estimator with 403 features.
# Fitting estimator with 393 features.
# Fitting estimator with 383 features.
# Fitting estimator with 373 features.
# Fitting estimator with 363 features.
# Fitting estimator with 353 features.
# Fitting estimator with 343 features.
# Fitting estimator with 333 features.
# Fitting estimator with 323 features.
# Fitting estimator with 313 features.
# Fitting estimator with 303 features.
# Fitting estimator with 293 features.
# Fitting estimator with 283 features.
# Fitting estimator with 273 features.
# Fitting estimator with 263 features.
# Fitting estimator with 253 features.
# Fitting estimator with 243 features.
# Fitting estimator with 233 features.
# Fitting estimator with 223 features.
# Fitting estimator with 213 features.
# Fitting estimator with 203 features.
# Fitting estimator with 193 features.
# Fitting estimator with 183 features.
# Fitting estimator with 173 features.
# Fitting estimator with 163 features.
# Fitting estimator with 153 features.
# Fitting estimator with 143 features.
# Fitting estimator with 133 features.
# Fitting estimator with 123 features.
# Fitting estimator with 113 features.
# Fitting estimator with 103 features.
# RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10,
#     verbose=5)

# %%
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ## <a id='2-3'>3. Embeded</a>
# - documentation for **SelectFromModel**: http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html
# ###  <a id='2-3-1'>3.1 Logistics Regression L1</a>
# **Note**
# - Normalization: Yes
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

embeded_lr_selector = SelectFromModel(LogisticRegression(penalty="l2"),threshold='1.25*median')
embeded_lr_selector.fit(X_norm, y)
# Out:
# SelectFromModel(estimator=LogisticRegression(), threshold='1.25*median')

# %%
embeded_lr_support = embeded_lr_selector.get_support()
embeded_lr_feature = X.loc[:,embeded_lr_support].columns.tolist()
print(str(len(embeded_lr_feature)), 'selected features')
# Out:
# 223 selected features

# %% [markdown]
# ###  <a id='2-3-2'>3.2 Random Forest</a>
# **Note**
# - Normalization: No
# - Impute missing values: Yes

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier

embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='1.25*median')
embeded_rf_selector.fit(X, y)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(), threshold='1.25*median')

# %%
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 233 selected features

# %%
cor_support
# Out:
# [False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True]

# %% [markdown]
# # <a id='3'>Summary</a>

# %%
pd.set_option('display.max_rows', None)
# put all selection together
feature_selection_df = pd.DataFrame({'Feature':cor_support, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support, 'Logistics':embeded_lr_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100).iloc[:,0].to_csv('selected_feature.csv', header=False, index=False)

# %%
feature_selection_df
# Out:
#      Feature  Pearson  Chi-2    RFE  Logistics  Random Forest  Total
# 1       True     True   True   True       True           True      6
# 2       True     True   True   True       True           True      6
# 3       True     True   True   True       True           True      6
# 4       True     True   True   True       True           True      6
# 5       True     True   True   True       True           True      6
# 6       True     True   True   True       True           True      6
# 7       True     True   True   True       True           True      6
# 8       True     True   True   True       True           True      6
# 9       True     True   True   True       True           True      6
# 10      True     True   True   True       True           True      6
# 11      True     True  False   True       True           True      5
# 12      True     True  False   True       True           True      5
# 13      True     True   True  False       True           True      5
# 14      True     True   True  False       True           True      5
# 15      True     True   True  False       True           True      5
# 16      True     True  False   True       True           True      5
# 17      True     True  False   True       True           True      5
# 18      True     True  False   True       True           True      5
# 19      True     True  False   True       True           True      5
# 20      True     True  False   True       True           True      5
# 21      True     True   True  False       True           True      5
# 22      True     True  False   True       True           True      5
# 23      True     True  False   True       True           True      5
# 24      True     True  False   True       True           True      5
# 25      True     True   True  False       True           True      5
# 26      True     True   True  False       True           True      5
# 27      True     True   True  False       True           True      5
# 28      True     True   True  False       True           True      5
# 29      True     True  False   True       True           True      5
# 30      True     True   True   True       True          False      5
# 31      True     True   True  False       True           True      5
# 32      True     True   True  False       True           True      5
# 33      True     True   True   True       True          False      5
# 34      True     True   True  False       True           True      5
# 35      True     True   True   True       True          False      5
# 36      True     True   True  False       True           True      5
# 37      True     True   True  False       True           True      5
# 38      True     True   True  False       True           True      5
# 39      True     True   True   True       True          False      5
# 40      True     True   True  False       True           True      5
# 41      True     True   True   True       True          False      5
# 42      True     True   True   True       True          False      5
# 43      True     True   True   True       True          False      5
# 44      True     True   True  False       True           True      5
# 45      True     True   True   True       True          False      5
# 46      True     True   True   True       True          False      5
# 47      True     True   True   True       True          False      5
# 48      True     True   True  False      False           True      4
# 49      True     True  False  False       True           True      4
# 50      True     True   True  False      False           True      4
# 51      True     True   True  False      False           True      4
# 52      True     True   True  False      False           True      4
# 53      True     True   True  False      False           True      4
# 54      True     True   True  False      False           True      4
# 55      True     True   True  False      False           True      4
# 56      True     True  False  False       True           True      4
# 57      True     True   True  False      False           True      4
# 58      True     True  False  False       True           True      4
# 59      True     True  False  False       True           True      4
# 60      True     True   True  False       True          False      4
# 61      True     True   True  False      False           True      4
# 62      True     True   True  False      False           True      4
# 63      True     True   True  False       True          False      4
# 64      True     True   True  False       True          False      4
# 65      True     True  False  False       True           True      4
# 66      True     True   True  False      False           True      4
# 67      True     True   True  False      False           True      4
# 68      True     True   True  False      False           True      4
# 69      True     True   True  False      False           True      4
# 70      True     True   True  False      False           True      4
# 71      True     True   True  False      False           True      4
# 72      True     True   True  False       True          False      4
# 73      True     True   True  False      False           True      4
# 74      True     True   True  False       True          False      4
# 75      True     True   True  False      False          False      3
# 76      True     True  False  False      False           True      3
# 77      True     True  False  False      False           True      3
# 78      True     True   True  False      False          False      3
# 79      True     True  False  False      False           True      3
# 80      True     True  False  False      False           True      3
# 81      True     True  False  False      False           True      3
# 82      True     True  False  False      False           True      3
# 83      True     True  False  False      False           True      3
# 84      True     True  False  False      False           True      3
# 85      True     True  False  False      False           True      3
# 86      True     True  False  False      False           True      3
# 87      True     True   True  False      False          False      3
# 88      True     True  False  False      False           True      3
# 89      True     True  False  False      False           True      3
# 90      True     True   True  False      False          False      3
# 91      True     True   True  False      False          False      3
# 92      True     True   True  False      False          False      3
# 93      True     True   True  False      False          False      3
# 94      True     True   True  False      False          False      3
# 95      True     True   True  False      False          False      3
# 96      True     True   True  False      False          False      3
# 97      True     True   True  False      False          False      3
# 98      True     True   True  False      False          False      3
# 99      True     True   True  False      False          False      3
# 100     True     True   True  False      False          False      3
# 101    False    False  False   True       True           True      3
# 102    False    False  False   True       True           True      3
# 103    False    False   True   True       True          False      3
# 104    False    False   True   True       True          False      3
# 105    False    False  False   True       True           True      3
# 106    False    False  False   True       True           True      3
# 107    False    False   True   True       True          False      3
# 108    False    False  False   True       True           True      3
# 109    False    False  False   True       True           True      3
# 110    False    False  False   True       True           True      3
# 111    False    False  False   True       True           True      3
# 112    False    False  False   True       True           True      3
# 113    False    False  False   True       True           True      3
# 114    False    False  False   True       True           True      3
# 115    False    False  False   True       True           True      3
# 116    False    False  False   True       True           True      3
# 117    False    False  False   True       True           True      3
# 118    False    False  False   True       True           True      3
# 119    False    False  False   True       True           True      3
# 120    False    False  False   True       True           True      3
# 121    False    False  False   True       True           True      3
# 122    False    False  False   True       True           True      3
# 123    False    False   True  False       True           True      3
# 124    False    False  False   True       True           True      3
# 125    False    False  False   True       True           True      3
# 126    False    False   True  False       True           True      3
# 127    False    False   True   True       True          False      3
# 128    False    False   True   True       True          False      3
# 129    False    False   True   True       True          False      3
# 130    False    False   True   True       True          False      3
# 131    False    False   True   True       True          False      3
# 132    False    False   True   True       True          False      3
# 133    False    False  False  False       True           True      2
# 134    False    False  False  False       True           True      2
# 135    False    False   True  False       True          False      2
# 136    False    False  False   True       True          False      2
# 137    False    False  False   True       True          False      2
# 138    False    False  False  False       True           True      2
# 139    False    False  False  False       True           True      2
# 140    False    False  False  False       True           True      2
# 141    False    False  False  False       True           True      2
# 142    False    False  False  False       True           True      2
# 143    False    False  False  False       True           True      2
# 144    False    False  False   True       True          False      2
# 145    False    False  False   True       True          False      2
# 146    False    False  False   True       True          False      2
# 147    False    False  False   True       True          False      2
# 148    False    False  False  False       True           True      2
# 149    False    False  False   True       True          False      2
# 150    False    False  False   True       True          False      2
# 151    False    False  False   True       True          False      2
# 152    False    False  False   True       True          False      2
# 153    False    False  False   True       True          False      2
# 154    False    False  False   True       True          False      2
# 155    False    False  False   True       True          False      2
# 156    False    False  False  False       True           True      2
# 157    False    False  False  False       True           True      2
# 158    False    False  False   True      False           True      2
# 159    False    False  False  False       True           True      2
# 160    False    False  False  False       True           True      2
# 161    False    False  False  False       True           True      2
# 162    False    False  False  False       True           True      2
# 163    False    False  False  False       True           True      2
# 164    False    False  False  False       True           True      2
# 165    False    False  False  False       True           True      2
# 166    False    False  False   True       True          False      2
# 167    False    False  False   True       True          False      2
# 168    False    False  False  False       True           True      2
# 169    False    False  False   True       True          False      2
# 170    False    False  False  False       True           True      2
# 171    False    False  False  False       True           True      2
# 172    False    False  False  False       True           True      2
# 173    False    False  False  False       True           True      2
# 174    False    False  False  False       True           True      2
# 175    False    False  False  False       True           True      2
# 176    False    False  False   True       True          False      2
# 177    False    False   True  False       True          False      2
# 178    False    False  False  False       True           True      2
# 179    False    False  False  False       True           True      2
# 180    False    False  False  False       True           True      2
# 181    False    False  False  False       True           True      2
# 182    False    False  False  False       True           True      2
# 183    False    False  False  False       True           True      2
# 184    False    False  False   True      False           True      2
# 185    False    False  False  False       True           True      2
# 186    False    False  False  False       True           True      2
# 187    False    False  False  False       True           True      2
# 188    False    False  False  False       True           True      2
# 189    False    False  False  False       True           True      2
# 190    False    False  False  False       True           True      2
# 191    False    False  False   True       True          False      2
# 192    False    False  False   True       True          False      2
# 193    False    False  False   True       True          False      2
# 194    False    False  False   True       True          False      2
# 195    False    False  False   True       True          False      2
# 196    False    False  False   True       True          False      2
# 197    False    False  False   True       True          False      2
# 198    False    False  False   True       True          False      2
# 199    False    False  False  False       True           True      2
# 200    False    False  False   True       True          False      2
# 201    False    False  False   True       True          False      2
# 202    False    False  False   True       True          False      2
# 203    False    False  False  False       True           True      2
# 204    False    False   True  False      False           True      2
# 205    False    False  False  False       True           True      2
# 206    False    False  False   True       True          False      2
# 207    False    False   True  False       True          False      2
# 208    False    False   True  False       True          False      2
# 209    False    False   True  False       True          False      2
# 210    False    False  False   True       True          False      2
# 211    False    False   True  False       True          False      2
# 212    False    False  False  False       True           True      2
# 213    False    False  False   True       True          False      2
# 214    False    False  False   True       True          False      2
# 215    False    False   True  False       True          False      2
# 216    False    False  False   True       True          False      2
# 217    False    False  False   True       True          False      2
# 218    False    False  False   True       True          False      2
# 219    False    False  False   True       True          False      2
# 220    False    False  False  False      False           True      1
# 221    False    False  False  False      False           True      1
# 222    False    False  False  False       True          False      1
# 223    False    False  False  False      False           True      1
# 224    False    False   True  False      False          False      1
# 225    False    False   True  False      False          False      1
# 226    False    False  False  False      False           True      1
# 227    False    False  False  False      False           True      1
# 228    False    False  False  False      False           True      1
# 229    False    False  False  False      False           True      1
# 230    False    False  False  False      False           True      1
# 231    False    False  False  False      False           True      1
# 232    False    False  False  False       True          False      1
# 233    False    False  False  False       True          False      1
# 234    False    False   True  False      False          False      1
# 235    False    False  False  False       True          False      1
# 236    False    False  False  False       True          False      1
# 237    False    False  False  False      False           True      1
# 238    False    False  False  False       True          False      1
# 239    False    False  False  False      False           True      1
# 240    False    False  False  False      False           True      1
# 241    False    False  False  False      False           True      1
# 242    False    False  False  False      False           True      1
# 243    False    False  False  False       True          False      1
# 244    False    False  False  False      False           True      1
# 245    False    False  False  False      False           True      1
# 246    False    False  False  False      False           True      1
# 247    False    False  False  False       True          False      1
# 248    False    False  False  False      False           True      1
# 249    False    False  False  False      False           True      1
# 250    False    False  False  False      False           True      1
# 251    False    False  False  False      False           True      1
# 252    False    False  False  False      False           True      1
# 253    False    False  False  False      False           True      1
# 254    False    False  False  False      False           True      1
# 255    False    False  False  False      False           True      1
# 256    False    False  False  False      False           True      1
# 257    False    False  False  False      False           True      1
# 258    False    False  False  False      False           True      1
# 259    False    False  False  False      False           True      1
# 260    False    False  False  False      False           True      1
# 261    False    False  False  False      False           True      1
# 262    False    False  False  False       True          False      1
# 263    False    False  False  False      False           True      1
# 264    False    False  False  False      False           True      1
# 265    False    False  False  False       True          False      1
# 266    False    False  False  False       True          False      1
# 267    False    False  False  False       True          False      1
# 268    False    False  False  False       True          False      1
# 269    False    False  False  False       True          False      1
# 270    False    False  False  False       True          False      1
# 271    False    False  False  False      False           True      1
# 272    False    False  False  False      False           True      1
# 273    False    False  False  False      False           True      1
# 274    False    False  False  False      False           True      1
# 275    False    False  False  False      False           True      1
# 276    False    False  False  False      False           True      1
# 277    False    False  False  False      False           True      1
# 278    False    False  False  False       True          False      1
# 279    False    False  False  False      False           True      1
# 280    False    False  False  False      False           True      1
# 281    False    False  False  False      False           True      1
# 282    False    False  False  False      False           True      1
# 283    False    False  False  False      False           True      1
# 284    False    False  False  False       True          False      1
# 285    False    False  False  False       True          False      1
# 286    False    False  False  False      False           True      1
# 287    False    False  False  False      False           True      1
# 288    False    False  False  False       True          False      1
# 289    False    False  False  False       True          False      1
# 290    False    False  False  False       True          False      1
# 291    False    False  False  False       True          False      1
# 292    False    False  False  False       True          False      1
# 293    False    False  False  False       True          False      1
# 294    False    False  False  False      False           True      1
# 295    False    False  False  False      False           True      1
# 296    False    False  False  False      False           True      1
# 297    False    False  False  False      False           True      1
# 298    False    False  False  False      False           True      1
# 299    False    False  False  False      False           True      1
# 300    False    False  False  False      False           True      1
# 301    False    False  False  False      False           True      1
# 302    False    False  False  False      False           True      1
# 303    False    False  False  False      False           True      1
# 304    False    False  False  False      False           True      1
# 305    False    False  False  False      False           True      1
# 306    False    False  False  False      False           True      1
# 307    False    False  False  False      False           True      1
# 308    False    False  False  False      False           True      1
# 309    False    False  False  False      False           True      1
# 310    False    False  False  False      False           True      1
# 311    False    False  False  False      False           True      1
# 312    False    False  False  False      False           True      1
# 313    False    False  False  False      False           True      1
# 314    False    False  False  False      False           True      1
# 315    False    False  False  False      False           True      1
# 316    False    False  False  False      False           True      1
# 317    False    False  False  False      False           True      1
# 318    False    False  False  False      False           True      1
# 319    False    False  False  False       True          False      1
# 320    False    False  False  False       True          False      1
# 321    False    False  False  False      False           True      1
# 322    False    False  False  False      False           True      1
# 323    False    False  False  False      False           True      1
# 324    False    False  False  False      False           True      1
# 325    False    False  False  False       True          False      1
# 326    False    False  False  False       True          False      1
# 327    False    False  False  False      False           True      1
# 328    False    False  False  False      False           True      1
# 329    False    False  False  False      False           True      1
# 330    False    False  False   True      False          False      1
# 331    False    False  False  False      False           True      1
# 332    False    False  False  False      False           True      1
# 333    False    False  False  False      False           True      1
# 334    False    False  False  False      False           True      1
# 335    False    False  False  False      False           True      1
# 336    False    False  False  False      False           True      1
# 337    False    False  False  False       True          False      1
# 338    False    False  False  False       True          False      1
# 339    False    False  False  False      False           True      1
# 340    False    False  False  False      False           True      1
# 341    False    False  False  False      False           True      1
# 342    False    False  False  False      False           True      1
# 343    False    False  False  False       True          False      1
# 344    False    False  False  False      False           True      1
# 345    False    False  False  False      False           True      1
# 346    False    False  False  False      False           True      1
# 347    False    False  False  False       True          False      1
# 348    False    False  False  False       True          False      1
# 349    False    False  False  False       True          False      1
# 350    False    False  False  False       True          False      1
# 351    False    False   True  False      False          False      1
# 352    False    False  False  False       True          False      1
# 353    False    False  False  False       True          False      1
# 354    False    False  False  False       True          False      1
# 355    False    False  False  False       True          False      1
# 356    False    False  False  False      False           True      1
# 357    False    False  False  False      False           True      1
# 358    False    False  False  False      False           True      1
# 359    False    False  False  False       True          False      1
# 360    False    False  False  False       True          False      1
# 361    False    False  False  False       True          False      1
# 362    False    False   True  False      False          False      1
# 363    False    False  False  False       True          False      1
# 364    False    False  False  False       True          False      1
# 365    False    False   True  False      False          False      1
# 366    False    False  False  False       True          False      1
# 367    False    False  False  False       True          False      1
# 368    False    False  False  False       True          False      1
# 369    False    False   True  False      False          False      1
# 370    False    False   True  False      False          False      1
# 371    False    False   True  False      False          False      1
# 372    False    False  False  False       True          False      1
# 373    False    False  False  False       True          False      1
# 374    False    False  False  False       True          False      1
# 375    False    False  False  False      False          False      0
# 376    False    False  False  False      False          False      0
# 377    False    False  False  False      False          False      0
# 378    False    False  False  False      False          False      0
# 379    False    False  False  False      False          False      0
# 380    False    False  False  False      False          False      0
# 381    False    False  False  False      False          False      0
# 382    False    False  False  False      False          False      0
# 383    False    False  False  False      False          False      0
# 384    False    False  False  False      False          False      0
# 385    False    False  False  False      False          False      0
# 386    False    False  False  False      False          False      0
# 387    False    False  False  False      False          False      0
# 388    False    False  False  False      False          False      0
# 389    False    False  False  False      False          False      0
# 390    False    False  False  False      False          False      0
# 391    False    False  False  False      False          False      0
# 392    False    False  False  False      False          False      0
# 393    False    False  False  False      False          False      0
# 394    False    False  False  False      False          False      0
# 395    False    False  False  False      False          False      0
# 396    False    False  False  False      False          False      0
# 397    False    False  False  False      False          False      0
# 398    False    False  False  False      False          False      0
# 399    False    False  False  False      False          False      0
# 400    False    False  False  False      False          False      0
# 401    False    False  False  False      False          False      0
# 402    False    False  False  False      False          False      0
# 403    False    False  False  False      False          False      0
# 404    False    False  False  False      False          False      0
# 405    False    False  False  False      False          False      0
# 406    False    False  False  False      False          False      0
# 407    False    False  False  False      False          False      0
# 408    False    False  False  False      False          False      0
# 409    False    False  False  False      False          False      0
# 410    False    False  False  False      False          False      0
# 411    False    False  False  False      False          False      0
# 412    False    False  False  False      False          False      0
# 413    False    False  False  False      False          False      0
# 414    False    False  False  False      False          False      0
# 415    False    False  False  False      False          False      0
# 416    False    False  False  False      False          False      0
# 417    False    False  False  False      False          False      0
# 418    False    False  False  False      False          False      0
# 419    False    False  False  False      False          False      0
# 420    False    False  False  False      False          False      0
# 421    False    False  False  False      False          False      0
# 422    False    False  False  False      False          False      0
# 423    False    False  False  False      False          False      0
# 424    False    False  False  False      False          False      0
# 425    False    False  False  False      False          False      0
# 426    False    False  False  False      False          False      0
# 427    False    False  False  False      False          False      0
# 428    False    False  False  False      False          False      0
# 429    False    False  False  False      False          False      0
# 430    False    False  False  False      False          False      0
# 431    False    False  False  False      False          False      0
# 432    False    False  False  False      False          False      0
# 433    False    False  False  False      False          False      0
# 434    False    False  False  False      False          False      0
# 435    False    False  False  False      False          False      0
# 436    False    False  False  False      False          False      0
# 437    False    False  False  False      False          False      0
# 438    False    False  False  False      False          False      0
# 439    False    False  False  False      False          False      0
# 440    False    False  False  False      False          False      0
# 441    False    False  False  False      False          False      0
# 442    False    False  False  False      False          False      0
# 443    False    False  False  False      False          False      0
# 444    False    False  False  False      False          False      0
# 445    False    False  False  False      False          False      0
# 446    False    False  False  False      False          False      0
# 447    False    False  False  False      False          False      0
# 448    False    False  False  False      False          False      0
# 449    False    False  False  False      False          False      0
# 450    False    False  False  False      False          False      0
# 451    False    False  False  False      False          False      0
# 452    False    False  False  False      False          False      0
# 453    False    False  False  False      False          False      0
# 454    False    False  False  False      False          False      0
# 455    False    False  False  False      False          False      0
# 456    False    False  False  False      False          False      0
# 457    False    False  False  False      False          False      0
# 458    False    False  False  False      False          False      0
# 459    False    False  False  False      False          False      0
# 460    False    False  False  False      False          False      0
# 461    False    False  False  False      False          False      0
# 462    False    False  False  False      False          False      0
# 463    False    False  False  False      False          False      0
# 464    False    False  False  False      False          False      0
# 465    False    False  False  False      False          False      0
# 466    False    False  False  False      False          False      0
# 467    False    False  False  False      False          False      0
# 468    False    False  False  False      False          False      0
# 469    False    False  False  False      False          False      0
# 470    False    False  False  False      False          False      0
# 471    False    False  False  False      False          False      0
# 472    False    False  False  False      False          False      0
# 473    False    False  False  False      False          False      0
# 474    False    False  False  False      False          False      0
# 475    False    False  False  False      False          False      0
# 476    False    False  False  False      False          False      0
# 477    False    False  False  False      False          False      0
# 478    False    False  False  False      False          False      0
# 479    False    False  False  False      False          False      0
# 480    False    False  False  False      False          False      0
# 481    False    False  False  False      False          False      0
# 482    False    False  False  False      False          False      0
# 483    False    False  False  False      False          False      0
# 484    False    False  False  False      False          False      0
# 485    False    False  False  False      False          False      0
# 486    False    False  False  False      False          False      0
# 487    False    False  False  False      False          False      0
# 488    False    False  False  False      False          False      0
# 489    False    False  False  False      False          False      0
# 490    False    False  False  False      False          False      0
# 491    False    False  False  False      False          False      0
# 492    False    False  False  False      False          False      0
# 493    False    False  False  False      False          False      0
# 494    False    False  False  False      False          False      0
# 495    False    False  False  False      False          False      0
# 496    False    False  False  False      False          False      0
# 497    False    False  False  False      False          False      0
# 498    False    False  False  False      False          False      0
# 499    False    False  False  False      False          False      0
# 500    False    False  False  False      False          False      0
# 501    False    False  False  False      False          False      0
# 502    False    False  False  False      False          False      0
# 503    False    False  False  False      False          False      0
# 504    False    False  False  False      False          False      0
# 505    False    False  False  False      False          False      0
# 506    False    False  False  False      False          False      0
# 507    False    False  False  False      False          False      0
# 508    False    False  False  False      False          False      0
# 509    False    False  False  False      False          False      0
# 510    False    False  False  False      False          False      0
# 511    False    False  False  False      False          False      0
# 512    False    False  False  False      False          False      0
# 513    False    False  False  False      False          False      0
